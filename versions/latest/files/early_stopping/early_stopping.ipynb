# %% [markdown]
# ## Trial-level early stopping in Ax
#
# This tutorial illustrates how to add a trial-level early stopping strategy to an Ax hyper-parameter optimization (HPO) loop. The goal of trial-level early stopping is to monitor the results of expensive evaluations and terminate those that are unlikely to produce promising results, freeing up resources to explore more configurations.
#
# Most of this tutorial is adapted from the [PyTorch Ax Multiobjective NAS Tutorial](https://pytorch.org/tutorials/intermediate/ax_multiobjective_nas_tutorial.html). The training job is different from the original in that we do not optimize `batch_size` or `epochs`. This was done for illustrative purposes, as each validation curve now has the same number of points. The companion training file `mnist_train_nas.py` has also been altered to log to Tensorboard during training.
#
# NOTE: Although the original NAS tutorial is for a multi-objective problem, this tutorial focuses on a single objective (validation accuracy) problem. Early stopping currently does not support \"true\" multi-objective stopping, although one can use [logical compositions of early stopping strategies](https://github.com/facebook/Ax/blob/main/ax/early_stopping/strategies/logical.py) to target multiple objectives separately. Early stopping for the multi-objective case is currently a work in progress.

# %%
import os
import tempfile

from pathlib import Path

import torchx

from ax.core import Experiment, Objective, ParameterType, RangeParameter, SearchSpace
from ax.core.optimization_config import OptimizationConfig

from ax.early_stopping.strategies import PercentileEarlyStoppingStrategy
from ax.metrics.tensorboard import TensorboardCurveMetric

from ax.modelbridge.dispatch_utils import choose_generation_strategy

from ax.runners.torchx import TorchXRunner

from ax.service.scheduler import Scheduler, SchedulerOptions
from ax.service.utils.report_utils import exp_to_df

from torchx import specs
from torchx.components import utils

from matplotlib import pyplot as plt

# %matplotlib inline

# %%
SMOKE_TEST = os.environ.get("SMOKE_TEST")

# %% [markdown]
# ## Defining the TorchX App
#
# Our goal is to optimize the PyTorch Lightning training job defined in
# [mnist_train_nas.py](https://github.com/pytorch/tutorials/tree/master/intermediate_source/mnist_train_nas.py)_.
# To do this using TorchX, we write a helper function that takes in
# the values of the architcture and hyperparameters of the training
# job and creates a [TorchX AppDef](https://pytorch.org/torchx/latest/basics.html)_
# with the appropriate settings.

# %%
if SMOKE_TEST:
    epochs = 3
else:
    epochs = 10

# %%
def trainer(
    log_path: str,
    hidden_size_1: int,
    hidden_size_2: int,
    learning_rate: float,
    dropout: float,
    trial_idx: int = -1,
) -> specs.AppDef:

    # define the log path so we can pass it to the TorchX AppDef
    if trial_idx >= 0:
        log_path = Path(log_path).joinpath(str(trial_idx)).absolute().as_posix()

    batch_size = 32

    return utils.python(
        # command line args to the training script
        "--log_path",
        log_path,
        "--hidden_size_1",
        str(hidden_size_1),
        "--hidden_size_2",
        str(hidden_size_2),
        "--learning_rate",
        str(learning_rate),
        "--epochs",
        str(epochs),
        "--dropout",
        str(dropout),
        "--batch_size",
        str(batch_size),
        # other config options
        name="trainer",
        script="tutorials/early_stopping/mnist_train_nas.py",
        image=torchx.version.TORCHX_IMAGE,
    )

# %% [markdown]
# ## Setting up the Runner
#
# Ax’s [Runner](https://ax.dev/api/core.html#ax.core.runner.Runner)
# abstraction allows writing interfaces to various backends.
# Ax already comes with Runner for TorchX, so we just need to
# configure it. For the purpose of this tutorial, we run jobs locally
# in a fully asynchronous fashion. In order to launch them on a cluster, you can instead specify a
# different TorchX scheduler and adjust the configuration appropriately.
# For example, if you have a Kubernetes cluster, you just need to change the
# scheduler from ``local_cwd`` to ``kubernetes``.
#
# The training job launched by this runner will log partial results to Tensorboard, which will then be monitored by the early stopping strategy. We will show how this is done using an Ax
# [TensorboardCurveMetric](https://ax.dev/api/metrics.html#module-ax.metrics.tensorboard) below.

# %%
# Make a temporary dir to log our results into
log_dir = tempfile.mkdtemp()

ax_runner = TorchXRunner(
    tracker_base="/tmp/",
    component=trainer,
    # NOTE: To launch this job on a cluster instead of locally you can
    # specify a different scheduler and adjust args appropriately.
    scheduler="local_cwd",
    component_const_params={"log_path": log_dir},
    cfg={},
)

# %% [markdown]
# ## Setting up the SearchSpace
#
# First, we define our search space. Ax supports both range parameters
# of type integer and float as well as choice parameters which can have
# non-numerical types such as strings.
# We will tune the hidden sizes, learning rate, and dropout parameters.

# %%
parameters = [
    # NOTE: In a real-world setting, hidden_size_1 and hidden_size_2
    # should probably be powers of 2, but in our simple example this
    # would mean that num_params can't take on that many values, which
    # in turn makes the Pareto frontier look pretty weird.
    RangeParameter(
        name="hidden_size_1",
        lower=16,
        upper=128,
        parameter_type=ParameterType.INT,
        log_scale=True,
    ),
    RangeParameter(
        name="hidden_size_2",
        lower=16,
        upper=128,
        parameter_type=ParameterType.INT,
        log_scale=True,
    ),
    RangeParameter(
        name="learning_rate",
        lower=1e-4,
        upper=1e-2,
        parameter_type=ParameterType.FLOAT,
        log_scale=True,
    ),
    RangeParameter(
        name="dropout",
        lower=0.0,
        upper=0.5,
        parameter_type=ParameterType.FLOAT,
    ),
]

search_space = SearchSpace(
    parameters=parameters,
    # NOTE: In practice, it may make sense to add a constraint
    # hidden_size_2 <= hidden_size_1
    parameter_constraints=[],
)

# %% [markdown]
# ## Setting up Metrics
#
# Ax has the concept of a Metric that defines properties of outcomes and how observations are obtained for these outcomes. This allows e.g. encodig how data is fetched from some distributed execution backend and post-processed before being passed as input to Ax.
#
# We will optimize the validation accuracy, which is a `TensorboardCurveMetric` that points to the logging directory assigned above. Note that we have set `is_available_while_running`, allowing for the metric to be queried as the trial progresses. This is critical for the early stopping strategy to monitor partial results.

# %%
class MyTensorboardMetric(TensorboardCurveMetric):

    # NOTE: We need to tell the new Tensorboard metric how to get the id /
    # file handle for the tensorboard logs from a trial. In this case
    # our convention is to just save a separate file per trial in
    # the pre-specified log dir.
    @classmethod
    def get_ids_from_trials(cls, trials):
        return {
            trial.index: Path(log_dir).joinpath(str(trial.index)).as_posix()
            for trial in trials
        }

    # This indicates whether the metric is queryable while the trial is
    # still running. This is required for early stopping to monitor the
    # progress of the running trial.ArithmeticError
    @classmethod
    def is_available_while_running(cls):
        return True

# %%
val_acc = MyTensorboardMetric(
    name="val_acc",
    curve_name="val_acc",
    lower_is_better=False,
)

# %% [markdown]
# ## Setting up the OptimizationConfig
#
# The `OptimizationConfig` specifies the objective for Ax to optimize.

# %%
opt_config = OptimizationConfig(
    objective=Objective(
        metric=val_acc,
        minimize=False,
    )
)

# %% [markdown]
# ## Defining an Early Stopping Strategy
#
# A `PercentileEarlyStoppingStrategy` is a simple method that stops a trial if its performance falls below a certain percentile of other trials at the same step (e.g., when `percentile_threshold` is 50, at a given point in time, if a trial ranks in the bottom 50% of trials, it is stopped).
# - We make use of `normalize_progressions` which normalizes the progression column (e.g. timestamp, epochs, training data used) to be in [0, 1]. This is useful because one doesn't need to know the maximum progression values of the curve (which might be, e.g., the total number of data points in the training dataset).
# - The `min_progression` parameter specifies that trials should only be considered for stopping if the latest progression value is greater than this threshold.
# - The `min_curves` parameter specifies the minimum number of completed curves (i.e., fully completed training jobs) before early stopping will be considered. This should be larger than zero if `normalize_progression` is used. In general, we want a few completed curves to have a baseline for comparison.
#
# Note that `PercentileEarlyStoppingStrategy` does not make use of learning curve modeling or prediction. More sophisticated model-based methods will be available in future versions of Ax.

# %%
percentile_early_stopping_strategy = PercentileEarlyStoppingStrategy(
    # stop if in bottom 70% of runs at the same progression
    percentile_threshold=70,
    # the trial must have passed `min_progression` steps before early stopping is initiated
    # note that we are using `normalize_progressions`, so this is on a scale of [0, 1]
    min_progression=0.3,
    # there must be `min_curves` completed trials and `min_curves` trials reporting data in
    # order for early stopping to be applicable
    min_curves=5,
    # specify, e.g., [0, 1] if the first two trials should never be stopped
    trial_indices_to_ignore=None,
    # check for new data every 10 seconds
    seconds_between_polls=10,
    normalize_progressions=True,
)

# %% [markdown]
# ## Creating the Ax Experiment
#
# In Ax, the Experiment object is the object that stores all the information about the problem setup.

# %%
experiment = Experiment(
    name="torchx_mnist",
    search_space=search_space,
    optimization_config=opt_config,
    runner=ax_runner,
)

# %% [markdown]
# ## Choosing the GenerationStrategy
#
# A [GenerationStrategy](https://ax.dev/api/modelbridge.html#ax.modelbridge.generation_strategy.GenerationStrategy)
# is the abstract representation of how we would like to perform the
# optimization. While this can be customized (if you’d like to do so, see
# [this tutorial](https://ax.dev/tutorials/generation_strategy.html)),
# in most cases Ax can automatically determine an appropriate strategy
# based on the search space, optimization config, and the total number
# of trials we want to run.
#
# Typically, Ax chooses to evaluate a number of random configurations
# before starting a model-based Bayesian Optimization strategy.
#
# We remark that in Ax, generation strategies and early stopping strategies are separate, a design decision motivated by ease-of-use. However, we should acknowledge that jointly considering generation and stopping using a single strategy would likely be the "proper" formulation.

# %%
if SMOKE_TEST:
    total_trials = 6
else:
    total_trials = 15  # total evaluation budget

gs = choose_generation_strategy(
    search_space=experiment.search_space,
    optimization_config=experiment.optimization_config,
    num_trials=total_trials,
)
# Out:
# [INFO 07-02 06:39:55] ax.modelbridge.dispatch_utils: Using Models.BOTORCH_MODULAR since there is at least one ordered parameter and there are no unordered categorical parameters.
# [INFO 07-02 06:39:55] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=4 num_trials=15 use_batch_trials=False
# [INFO 07-02 06:39:55] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=5
# [INFO 07-02 06:39:55] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=5
# [INFO 07-02 06:39:55] ax.modelbridge.dispatch_utils: `verbose`, `disable_progbar`, and `jit_compile` are not yet supported when using `choose_generation_strategy` with ModularBoTorchModel, dropping these arguments.
# [INFO 07-02 06:39:55] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+BoTorch', steps=[Sobol for 5 trials, BoTorch for subsequent trials]). Iterations after 5 will take longer to generate due to model-fitting.

# %% [markdown]
# ## Configuring the Scheduler
#
# The `Scheduler` acts as the loop control for the optimization.
# It communicates with the backend to launch trials, check their status, retrieve (partial) results, and importantly for this tutorial, calls the early stopping strategy. If the early stopping strategy suggests a trial to be the stopped, the `Scheduler` communicates with the backend to terminate the trial.
#
# The ``Scheduler`` requires the ``Experiment`` and the ``GenerationStrategy``.
# A set of options can be passed in via ``SchedulerOptions``. Here, we
# configure the number of total evaluations as well as ``max_pending_trials``,
# the maximum number of trials that should run concurrently. In our
# local setting, this is the number of training jobs running as individual
# processes, while in a remote execution setting, this would be the number
# of machines you want to use in parallel.

# %%
scheduler = Scheduler(
    experiment=experiment,
    generation_strategy=gs,
    options=SchedulerOptions(
        total_trials=total_trials,
        max_pending_trials=5,
        early_stopping_strategy=percentile_early_stopping_strategy,
    ),
)
# Out:
# [INFO 07-02 06:39:55] Scheduler: `Scheduler` requires experiment to have immutable search space and optimization config. Setting property immutable_search_space_and_opt_config to `True` on experiment.

# %%
# %%time
scheduler.run_all_trials()
# Out:
# [INFO 07-02 06:39:55] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 06:39:55] ax.early_stopping.strategies.base: PercentileEarlyStoppingStrategy received empty data. Not stopping any trials.
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/modelbridge/cross_validation.py:544: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 07-02 06:39:55] Scheduler: Running trials [0]...
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/modelbridge/cross_validation.py:544: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 07-02 06:39:56] Scheduler: Running trials [1]...
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/modelbridge/cross_validation.py:544: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 07-02 06:39:57] Scheduler: Running trials [2]...
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/modelbridge/cross_validation.py:544: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 07-02 06:39:58] Scheduler: Running trials [3]...
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/modelbridge/cross_validation.py:544: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 07-02 06:39:59] Scheduler: Running trials [4]...
# [WARNING 07-02 06:40:00] Scheduler: Both `init_seconds_between_polls` and `early_stopping_strategy supplied. `init_seconds_between_polls=1` will be overrridden by `early_stopping_strategy.seconds_between_polls=10` and polling will take place at a constant rate.
# [INFO 07-02 06:40:00] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 06:40:00] Scheduler: Fetching data for trials: 0 - 4 because some metrics on experiment are available while trials are running.
# [INFO 07-02 06:40:00] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/0. Returning without this metric.
# [INFO 07-02 06:40:00] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/1. Returning without this metric.
# [INFO 07-02 06:40:00] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/2. Returning without this metric.
# [INFO 07-02 06:40:00] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/3. Returning without this metric.
# [INFO 07-02 06:40:00] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/4. Returning without this metric.
# [INFO 07-02 06:40:00] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:00] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:00] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:00] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:00] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [ERROR 07-02 06:40:00] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:00] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:00] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:00] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:00] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [WARNING 07-02 06:40:00] Scheduler: Failed to fetch val_acc for trial 0, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:00] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 0 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:00] Scheduler: Failed to fetch val_acc for trial 1, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:00] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 1 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:00] Scheduler: Failed to fetch val_acc for trial 2, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:00] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 2 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:00] Scheduler: Failed to fetch val_acc for trial 3, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:00] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 3 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:00] Scheduler: Failed to fetch val_acc for trial 4, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:00] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 4 is still RUNNING continuing the experiment and retrying on next poll...
# [INFO 07-02 06:40:00] ax.early_stopping.strategies.base: PercentileEarlyStoppingStrategy received empty data. Not stopping any trials.
# [INFO 07-02 06:40:00] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 5).
# [INFO 07-02 06:40:10] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 06:40:10] Scheduler: Fetching data for trials: 0 - 4 because some metrics on experiment are available while trials are running.
# [INFO 07-02 06:40:10] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/0. Returning without this metric.
# [INFO 07-02 06:40:10] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/1. Returning without this metric.
# [INFO 07-02 06:40:10] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/2. Returning without this metric.
# [INFO 07-02 06:40:10] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/3. Returning without this metric.
# [INFO 07-02 06:40:10] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/4. Returning without this metric.
# [INFO 07-02 06:40:10] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:10] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:10] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:10] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:10] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [ERROR 07-02 06:40:10] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:10] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:10] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:10] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:10] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [WARNING 07-02 06:40:10] Scheduler: Failed to fetch val_acc for trial 0, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:10] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 0 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:10] Scheduler: Failed to fetch val_acc for trial 1, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:10] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 1 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:10] Scheduler: Failed to fetch val_acc for trial 2, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:10] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 2 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:10] Scheduler: Failed to fetch val_acc for trial 3, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:10] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 3 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:10] Scheduler: Failed to fetch val_acc for trial 4, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:10] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 4 is still RUNNING continuing the experiment and retrying on next poll...
# [INFO 07-02 06:40:10] ax.early_stopping.strategies.base: PercentileEarlyStoppingStrategy received empty data. Not stopping any trials.
# [INFO 07-02 06:40:10] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 5).
# [INFO 07-02 06:40:20] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 06:40:20] Scheduler: Fetching data for trials: 0 - 4 because some metrics on experiment are available while trials are running.
# [INFO 07-02 06:40:20] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/0. Returning without this metric.
# [INFO 07-02 06:40:20] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/1. Returning without this metric.
# [INFO 07-02 06:40:20] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/2. Returning without this metric.
# [INFO 07-02 06:40:20] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/3. Returning without this metric.
# [INFO 07-02 06:40:20] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/4. Returning without this metric.
# [INFO 07-02 06:40:20] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:20] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:20] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:20] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:20] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [ERROR 07-02 06:40:20] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:20] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:20] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:20] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:20] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [WARNING 07-02 06:40:20] Scheduler: Failed to fetch val_acc for trial 0, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:20] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 0 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:20] Scheduler: Failed to fetch val_acc for trial 1, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:20] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 1 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:20] Scheduler: Failed to fetch val_acc for trial 2, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:20] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 2 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:20] Scheduler: Failed to fetch val_acc for trial 3, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:20] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 3 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:20] Scheduler: Failed to fetch val_acc for trial 4, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:20] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 4 is still RUNNING continuing the experiment and retrying on next poll...
# [INFO 07-02 06:40:20] ax.early_stopping.strategies.base: PercentileEarlyStoppingStrategy received empty data. Not stopping any trials.
# [INFO 07-02 06:40:20] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 5).
# [INFO 07-02 06:40:30] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 06:40:30] Scheduler: Fetching data for trials: 0 - 4 because some metrics on experiment are available while trials are running.
# [INFO 07-02 06:40:30] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/0. Returning without this metric.
# [INFO 07-02 06:40:30] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/1. Returning without this metric.
# [INFO 07-02 06:40:30] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/2. Returning without this metric.
# [INFO 07-02 06:40:30] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/3. Returning without this metric.
# [INFO 07-02 06:40:30] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/4. Returning without this metric.
# [INFO 07-02 06:40:30] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:30] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:30] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:30] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:30] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [ERROR 07-02 06:40:30] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:30] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:30] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:30] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:30] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [WARNING 07-02 06:40:30] Scheduler: Failed to fetch val_acc for trial 0, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:30] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 0 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:30] Scheduler: Failed to fetch val_acc for trial 1, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:30] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 1 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:30] Scheduler: Failed to fetch val_acc for trial 2, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:30] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 2 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:30] Scheduler: Failed to fetch val_acc for trial 3, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:30] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 3 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:30] Scheduler: Failed to fetch val_acc for trial 4, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:30] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 4 is still RUNNING continuing the experiment and retrying on next poll...
# [INFO 07-02 06:40:30] ax.early_stopping.strategies.base: PercentileEarlyStoppingStrategy received empty data. Not stopping any trials.
# [INFO 07-02 06:40:30] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 5).
# [INFO 07-02 06:40:40] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 06:40:40] Scheduler: Fetching data for trials: 0 - 4 because some metrics on experiment are available while trials are running.
# [INFO 07-02 06:40:40] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/0. Returning without this metric.
# [INFO 07-02 06:40:40] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/1. Returning without this metric.
# [INFO 07-02 06:40:40] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/2. Returning without this metric.
# [INFO 07-02 06:40:40] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/3. Returning without this metric.
# [INFO 07-02 06:40:40] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/4. Returning without this metric.
# [INFO 07-02 06:40:40] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:40] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:40] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:40] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:40] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [ERROR 07-02 06:40:40] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:40] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:40] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:40] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:40] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [WARNING 07-02 06:40:40] Scheduler: Failed to fetch val_acc for trial 0, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:40] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 0 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:40] Scheduler: Failed to fetch val_acc for trial 1, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:40] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 1 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:40] Scheduler: Failed to fetch val_acc for trial 2, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:40] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 2 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:40] Scheduler: Failed to fetch val_acc for trial 3, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:40] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 3 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:40] Scheduler: Failed to fetch val_acc for trial 4, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:40] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 4 is still RUNNING continuing the experiment and retrying on next poll...
# [INFO 07-02 06:40:40] ax.early_stopping.strategies.base: PercentileEarlyStoppingStrategy received empty data. Not stopping any trials.
# [INFO 07-02 06:40:40] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 5).
# [INFO 07-02 06:40:50] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 06:40:50] Scheduler: Fetching data for trials: 0 - 4 because some metrics on experiment are available while trials are running.
# [INFO 07-02 06:40:50] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/0. Returning without this metric.
# [INFO 07-02 06:40:50] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/1. Returning without this metric.
# [INFO 07-02 06:40:50] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/2. Returning without this metric.
# [INFO 07-02 06:40:50] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/3. Returning without this metric.
# [INFO 07-02 06:40:50] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/4. Returning without this metric.
# [INFO 07-02 06:40:50] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:50] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:50] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:50] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:40:50] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [ERROR 07-02 06:40:50] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:50] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:50] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:50] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:40:50] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [WARNING 07-02 06:40:50] Scheduler: Failed to fetch val_acc for trial 0, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:50] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 0 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:50] Scheduler: Failed to fetch val_acc for trial 1, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:50] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 1 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:50] Scheduler: Failed to fetch val_acc for trial 2, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:50] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 2 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:50] Scheduler: Failed to fetch val_acc for trial 3, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:50] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 3 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:40:50] Scheduler: Failed to fetch val_acc for trial 4, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:40:50] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 4 is still RUNNING continuing the experiment and retrying on next poll...
# [INFO 07-02 06:40:50] ax.early_stopping.strategies.base: PercentileEarlyStoppingStrategy received empty data. Not stopping any trials.
# [INFO 07-02 06:40:50] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 5).
# [INFO 07-02 06:41:00] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 06:41:00] Scheduler: Fetching data for trials: 0 - 4 because some metrics on experiment are available while trials are running.
# [INFO 07-02 06:41:00] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/0. Returning without this metric.
# [INFO 07-02 06:41:00] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/1. Returning without this metric.
# [INFO 07-02 06:41:00] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/2. Returning without this metric.
# [INFO 07-02 06:41:00] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/3. Returning without this metric.
# [INFO 07-02 06:41:00] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/4. Returning without this metric.
# [INFO 07-02 06:41:00] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:00] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:00] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:00] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:00] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [ERROR 07-02 06:41:00] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:00] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:00] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:00] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:00] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [WARNING 07-02 06:41:01] Scheduler: Failed to fetch val_acc for trial 0, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:01] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 0 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:01] Scheduler: Failed to fetch val_acc for trial 1, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:01] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 1 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:01] Scheduler: Failed to fetch val_acc for trial 2, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:01] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 2 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:01] Scheduler: Failed to fetch val_acc for trial 3, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:01] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 3 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:01] Scheduler: Failed to fetch val_acc for trial 4, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:01] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 4 is still RUNNING continuing the experiment and retrying on next poll...
# [INFO 07-02 06:41:01] ax.early_stopping.strategies.base: PercentileEarlyStoppingStrategy received empty data. Not stopping any trials.
# [INFO 07-02 06:41:01] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 5).
# [INFO 07-02 06:41:11] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 06:41:11] Scheduler: Fetching data for trials: 0 - 4 because some metrics on experiment are available while trials are running.
# [INFO 07-02 06:41:11] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/0. Returning without this metric.
# [INFO 07-02 06:41:11] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/1. Returning without this metric.
# [INFO 07-02 06:41:11] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/2. Returning without this metric.
# [INFO 07-02 06:41:11] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/3. Returning without this metric.
# [INFO 07-02 06:41:11] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/4. Returning without this metric.
# [INFO 07-02 06:41:11] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:11] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:11] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:11] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:11] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [ERROR 07-02 06:41:11] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:11] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:11] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:11] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:11] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [WARNING 07-02 06:41:11] Scheduler: Failed to fetch val_acc for trial 0, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:11] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 0 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:11] Scheduler: Failed to fetch val_acc for trial 1, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:11] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 1 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:11] Scheduler: Failed to fetch val_acc for trial 2, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:11] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 2 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:11] Scheduler: Failed to fetch val_acc for trial 3, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:11] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 3 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:11] Scheduler: Failed to fetch val_acc for trial 4, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:11] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 4 is still RUNNING continuing the experiment and retrying on next poll...
# [INFO 07-02 06:41:11] ax.early_stopping.strategies.base: PercentileEarlyStoppingStrategy received empty data. Not stopping any trials.
# [INFO 07-02 06:41:11] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 5).
# [INFO 07-02 06:41:21] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 06:41:21] Scheduler: Fetching data for trials: 0 - 4 because some metrics on experiment are available while trials are running.
# [INFO 07-02 06:41:21] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/0. Returning without this metric.
# [INFO 07-02 06:41:21] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/1. Returning without this metric.
# [INFO 07-02 06:41:21] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/2. Returning without this metric.
# [INFO 07-02 06:41:21] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/3. Returning without this metric.
# [INFO 07-02 06:41:21] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/4. Returning without this metric.
# [INFO 07-02 06:41:21] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:21] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:21] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:21] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:21] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [ERROR 07-02 06:41:21] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:21] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:21] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:21] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:21] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [WARNING 07-02 06:41:21] Scheduler: Failed to fetch val_acc for trial 0, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:21] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 0 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:21] Scheduler: Failed to fetch val_acc for trial 1, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:21] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 1 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:21] Scheduler: Failed to fetch val_acc for trial 2, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:21] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 2 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:21] Scheduler: Failed to fetch val_acc for trial 3, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:21] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 3 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:21] Scheduler: Failed to fetch val_acc for trial 4, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:21] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 4 is still RUNNING continuing the experiment and retrying on next poll...
# [INFO 07-02 06:41:21] ax.early_stopping.strategies.base: PercentileEarlyStoppingStrategy received empty data. Not stopping any trials.
# [INFO 07-02 06:41:21] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 5).
# [INFO 07-02 06:41:31] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 06:41:31] Scheduler: Fetching data for trials: 0 - 4 because some metrics on experiment are available while trials are running.
# [INFO 07-02 06:41:31] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/0. Returning without this metric.
# [INFO 07-02 06:41:31] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/1. Returning without this metric.
# [INFO 07-02 06:41:31] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/2. Returning without this metric.
# [INFO 07-02 06:41:31] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/3. Returning without this metric.
# [INFO 07-02 06:41:31] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/4. Returning without this metric.
# [INFO 07-02 06:41:31] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:31] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:31] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:31] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:31] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [ERROR 07-02 06:41:31] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:31] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:31] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:31] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [ERROR 07-02 06:41:31] ax.core.experiment: Discovered Metric fetching Err while attaching data MetricFetchE(message="DataFrame from curve series is empty"). Ignoring for now -- will retry query on next call to fetch.
# [WARNING 07-02 06:41:31] Scheduler: Failed to fetch val_acc for trial 0, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:31] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 0 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:31] Scheduler: Failed to fetch val_acc for trial 1, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:31] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 1 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:31] Scheduler: Failed to fetch val_acc for trial 2, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:31] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 2 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:31] Scheduler: Failed to fetch val_acc for trial 3, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:31] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 3 is still RUNNING continuing the experiment and retrying on next poll...
# [WARNING 07-02 06:41:31] Scheduler: Failed to fetch val_acc for trial 4, found MetricFetchE(message="DataFrame from curve series is empty").
# [INFO 07-02 06:41:31] Scheduler: MetricFetchE INFO: Because val_acc is available_while_running and trial 4 is still RUNNING continuing the experiment and retrying on next poll...
# [INFO 07-02 06:41:31] ax.early_stopping.strategies.base: PercentileEarlyStoppingStrategy received empty data. Not stopping any trials.
# [INFO 07-02 06:41:31] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 5).
# [INFO 07-02 06:41:41] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 06:41:41] Scheduler: Fetching data for trials: 0 - 4 because some metrics on experiment are available while trials are running.
# [INFO 07-02 06:41:41] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/0. Returning without this metric.
# [INFO 07-02 06:41:41] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/1. Returning without this metric.
# [INFO 07-02 06:41:41] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/2. Returning without this metric.
# [INFO 07-02 06:41:41] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/3. Returning without this metric.
# [INFO 07-02 06:41:41] ax.metrics.curve: val_acc not yet present in curves from /tmp/tmpberwh4ur/4. Returning without this metric.
# [INFO 07-02 06:41:41] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:41] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:41] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:41] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# [INFO 07-02 06:41:41] ax.core.metric: MetricFetchE INFO: Initialized MetricFetchE(message="DataFrame from curve series is empty")
# ...
# [INFO 07-02 07:13:47] ax.early_stopping.strategies.base: Last progression of Trial 13 is 0.5999466666666666.
# [INFO 07-02 07:13:47] ax.early_stopping.strategies.percentile: Early stopping objective at last progression is:
# 0     0.917063
# 1     0.940335
# 2     0.924245
# 3     0.953757
# 4     0.946050
# 6     0.966622
# 12    0.966302
# 13    0.966468
# 14    0.964450
# Name: 0.5999466666666666, dtype: float64.
# [INFO 07-02 07:13:47] ax.early_stopping.strategies.percentile: Early stopping decision for 13: False. Reason: Trial objective value 0.966468095779419 is better than 70.0-th percentile (0.9655610680580139) across comparable trials.
# [INFO 07-02 07:13:47] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 2).
# [INFO 07-02 07:13:57] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 07:13:57] Scheduler: Fetching data for trials: 12 - 13 because some metrics on experiment are available while trials are running.
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# [INFO 07-02 07:13:57] ax.early_stopping.strategies.base: Last progression of any candidate for trial stopping is 0.7999466666666667.
# [INFO 07-02 07:13:57] ax.early_stopping.strategies.percentile: Considering trial 12 for early stopping.
# [INFO 07-02 07:13:57] ax.early_stopping.strategies.base: Last progression of Trial 12 is 0.7999466666666667.
# [INFO 07-02 07:13:57] ax.early_stopping.strategies.percentile: Early stopping objective at last progression is:
# 0     0.925568
# 1     0.945793
# 2     0.926734
# 3     0.955279
# 4     0.949465
# 6     0.970155
# 12    0.971165
# Name: 0.7999466666666667, dtype: float64.
# [INFO 07-02 07:13:57] ax.early_stopping.strategies.percentile: Early stopping decision for 12: False. Reason: Trial objective value 0.9711652398109436 is better than 70.0-th percentile (0.9582540154457092) across comparable trials.
# [INFO 07-02 07:13:57] ax.early_stopping.strategies.percentile: Considering trial 13 for early stopping.
# [INFO 07-02 07:13:57] ax.early_stopping.strategies.base: Last progression of Trial 13 is 0.6999466666666667.
# [INFO 07-02 07:13:57] ax.early_stopping.strategies.percentile: Early stopping objective at last progression is:
# 0     0.924622
# 1     0.942666
# 2     0.928418
# 3     0.955534
# 4     0.948069
# 6     0.969580
# 12    0.967891
# 13    0.967148
# Name: 0.6999466666666667, dtype: float64.
# [INFO 07-02 07:13:57] ax.early_stopping.strategies.percentile: Early stopping decision for 13: False. Reason: Trial objective value 0.9671481251716614 is better than 70.0-th percentile (0.9659866631031037) across comparable trials.
# [INFO 07-02 07:13:57] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 2).
# [INFO 07-02 07:14:07] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 07:14:07] Scheduler: Fetching data for trials: 12 - 13 because some metrics on experiment are available while trials are running.
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# [INFO 07-02 07:14:07] ax.early_stopping.strategies.base: Last progression of any candidate for trial stopping is 0.8999466666666667.
# [INFO 07-02 07:14:07] ax.early_stopping.strategies.percentile: Considering trial 12 for early stopping.
# [INFO 07-02 07:14:07] ax.early_stopping.strategies.base: Last progression of Trial 12 is 0.8999466666666667.
# [INFO 07-02 07:14:07] ax.early_stopping.strategies.percentile: Early stopping objective at last progression is:
# 0     0.927854
# 1     0.948206
# 2     0.930791
# 3     0.958342
# 4     0.950713
# 6     0.971029
# 12    0.972694
# Name: 0.8999466666666667, dtype: float64.
# [INFO 07-02 07:14:07] ax.early_stopping.strategies.percentile: Early stopping decision for 12: False. Reason: Trial objective value 0.972693681716919 is better than 70.0-th percentile (0.9608797311782837) across comparable trials.
# [INFO 07-02 07:14:07] ax.early_stopping.strategies.percentile: Considering trial 13 for early stopping.
# [INFO 07-02 07:14:07] ax.early_stopping.strategies.base: Last progression of Trial 13 is 0.6999466666666667.
# [INFO 07-02 07:14:07] ax.early_stopping.strategies.percentile: Early stopping objective at last progression is:
# 0     0.924622
# 1     0.942666
# 2     0.928418
# 3     0.955534
# 4     0.948069
# 6     0.969580
# 12    0.967891
# 13    0.967148
# Name: 0.6999466666666667, dtype: float64.
# [INFO 07-02 07:14:07] ax.early_stopping.strategies.percentile: Early stopping decision for 13: False. Reason: Trial objective value 0.9671481251716614 is better than 70.0-th percentile (0.9659866631031037) across comparable trials.
# [INFO 07-02 07:14:07] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 2).
# [INFO 07-02 07:14:17] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 07:14:17] Scheduler: Fetching data for trials: 12 - 13 because some metrics on experiment are available while trials are running.
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# [INFO 07-02 07:14:17] ax.early_stopping.strategies.base: Last progression of any candidate for trial stopping is 0.8999466666666667.
# [INFO 07-02 07:14:18] ax.early_stopping.strategies.percentile: Considering trial 12 for early stopping.
# [INFO 07-02 07:14:18] ax.early_stopping.strategies.base: Last progression of Trial 12 is 0.8999466666666667.
# [INFO 07-02 07:14:18] ax.early_stopping.strategies.percentile: Early stopping objective at last progression is:
# 0     0.927854
# 1     0.948206
# 2     0.930791
# 3     0.958342
# 4     0.950713
# 6     0.971029
# 12    0.972694
# Name: 0.8999466666666667, dtype: float64.
# [INFO 07-02 07:14:18] ax.early_stopping.strategies.percentile: Early stopping decision for 12: False. Reason: Trial objective value 0.972693681716919 is better than 70.0-th percentile (0.9608797311782837) across comparable trials.
# [INFO 07-02 07:14:18] ax.early_stopping.strategies.percentile: Considering trial 13 for early stopping.
# [INFO 07-02 07:14:18] ax.early_stopping.strategies.base: Last progression of Trial 13 is 0.7999466666666667.
# [INFO 07-02 07:14:18] ax.early_stopping.strategies.percentile: Early stopping objective at last progression is:
# 0     0.925568
# 1     0.945793
# 2     0.926734
# 3     0.955279
# 4     0.949465
# 6     0.970155
# 12    0.971165
# 13    0.968045
# Name: 0.7999466666666667, dtype: float64.
# [INFO 07-02 07:14:18] ax.early_stopping.strategies.percentile: Early stopping decision for 13: False. Reason: Trial objective value 0.9680446982383728 is better than 70.0-th percentile (0.9667680978775024) across comparable trials.
# [INFO 07-02 07:14:18] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 2).
# [INFO 07-02 07:14:28] Scheduler: Fetching data for newly completed trials: [12].
# [INFO 07-02 07:14:28] Scheduler: Fetching data for trials: [13] because some metrics on experiment are available while trials are running.
# [INFO 07-02 07:14:28] Scheduler: Retrieved COMPLETED trials: [12].
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# [INFO 07-02 07:14:28] ax.early_stopping.strategies.base: Last progression of any candidate for trial stopping is 0.7999466666666667.
# [INFO 07-02 07:14:28] ax.early_stopping.strategies.percentile: Considering trial 13 for early stopping.
# [INFO 07-02 07:14:28] ax.early_stopping.strategies.base: Last progression of Trial 13 is 0.7999466666666667.
# [INFO 07-02 07:14:28] ax.early_stopping.strategies.percentile: Early stopping objective at last progression is:
# 0     0.925568
# 1     0.945793
# 2     0.926734
# 3     0.955279
# 4     0.949465
# 6     0.970155
# 12    0.971165
# 13    0.968045
# Name: 0.7999466666666667, dtype: float64.
# [INFO 07-02 07:14:28] ax.early_stopping.strategies.percentile: Early stopping decision for 13: False. Reason: Trial objective value 0.9680446982383728 is better than 70.0-th percentile (0.9667680978775024) across comparable trials.
# [WARNING 07-02 07:14:28] Scheduler: Both `init_seconds_between_polls` and `early_stopping_strategy supplied. `init_seconds_between_polls=1` will be overrridden by `early_stopping_strategy.seconds_between_polls=10` and polling will take place at a constant rate.
# [INFO 07-02 07:14:28] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 07:14:28] Scheduler: Fetching data for trials: [13] because some metrics on experiment are available while trials are running.
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# [INFO 07-02 07:14:28] ax.early_stopping.strategies.base: Last progression of any candidate for trial stopping is 0.7999466666666667.
# [INFO 07-02 07:14:28] ax.early_stopping.strategies.percentile: Considering trial 13 for early stopping.
# [INFO 07-02 07:14:28] ax.early_stopping.strategies.base: Last progression of Trial 13 is 0.7999466666666667.
# [INFO 07-02 07:14:28] ax.early_stopping.strategies.percentile: Early stopping objective at last progression is:
# 0     0.925568
# 1     0.945793
# 2     0.926734
# 3     0.955279
# 4     0.949465
# 6     0.970155
# 12    0.971165
# 13    0.968045
# Name: 0.7999466666666667, dtype: float64.
# [INFO 07-02 07:14:28] ax.early_stopping.strategies.percentile: Early stopping decision for 13: False. Reason: Trial objective value 0.9680446982383728 is better than 70.0-th percentile (0.9667680978775024) across comparable trials.
# [INFO 07-02 07:14:28] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 1).
# [INFO 07-02 07:14:38] Scheduler: Fetching data for newly completed trials: [].
# [INFO 07-02 07:14:38] Scheduler: Fetching data for trials: [13] because some metrics on experiment are available while trials are running.
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# [INFO 07-02 07:14:38] ax.early_stopping.strategies.base: Last progression of any candidate for trial stopping is 0.8999466666666667.
# [INFO 07-02 07:14:38] ax.early_stopping.strategies.percentile: Considering trial 13 for early stopping.
# [INFO 07-02 07:14:38] ax.early_stopping.strategies.base: Last progression of Trial 13 is 0.8999466666666667.
# [INFO 07-02 07:14:38] ax.early_stopping.strategies.percentile: Early stopping objective at last progression is:
# 0     0.927854
# 1     0.948206
# 2     0.930791
# 3     0.958342
# 4     0.950713
# 6     0.971029
# 12    0.972694
# 13    0.966771
# Name: 0.8999466666666667, dtype: float64.
# [INFO 07-02 07:14:38] ax.early_stopping.strategies.percentile: Early stopping decision for 13: False. Reason: Trial objective value 0.9667707085609436 is better than 70.0-th percentile (0.9659278869628907) across comparable trials.
# [INFO 07-02 07:14:38] Scheduler: Waiting for completed trials (for 10 sec, currently running trials: 1).
# [INFO 07-02 07:14:48] Scheduler: Fetching data for newly completed trials: [13].
# [INFO 07-02 07:14:48] Scheduler: Retrieved COMPLETED trials: [13].
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# [INFO 07-02 07:14:48] ax.early_stopping.strategies.base: Last progression of any candidate for trial stopping is 0.
# [INFO 07-02 07:14:48] ax.early_stopping.strategies.base: No trials have reached 0.3. Not stopping any trials.
# [WARNING 07-02 07:14:48] Scheduler: Both `init_seconds_between_polls` and `early_stopping_strategy supplied. `init_seconds_between_polls=1` will be overrridden by `early_stopping_strategy.seconds_between_polls=10` and polling will take place at a constant rate.
# CPU times: user 1min 23s, sys: 1.57 s, total: 1min 25s
# Wall time: 34min 53s
# OptimizationResult()

# %% [markdown]
# ## Results
#
# First, we examine the data stored on the experiment. This shows that each trial is associated with an entire learning curve, represented by the column "steps".

# %%
experiment.lookup_data().map_df.head(n=10)
# Out:
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
#   arm_name metric_name      mean  sem  trial_index    steps
# 0      0_0     val_acc  0.893962  NaN            0   1874.0
# 1      0_0     val_acc  0.917171  NaN            0   3749.0
# 2      0_0     val_acc  0.906981  NaN            0   5624.0
# 3      0_0     val_acc  0.917114  NaN            0   7499.0
# 4      0_0     val_acc  0.917637  NaN            0   9374.0
# 5      0_0     val_acc  0.917063  NaN            0  11249.0
# 6      0_0     val_acc  0.924622  NaN            0  13124.0
# 7      0_0     val_acc  0.925568  NaN            0  14999.0
# 8      0_0     val_acc  0.927854  NaN            0  16874.0
# 9      0_0     val_acc  0.923018  NaN            0  18749.0

# %% [markdown]
# Below is a summary of the experiment, showing that a portion of trials have been early stopped.

# %%
exp_to_df(experiment)
# Out:
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# [WARNING 07-02 07:14:49] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
#     trial_index arm_name   trial_status generation_method   val_acc  \
# 0             0      0_0      COMPLETED             Sobol  0.923018
# 1             1      1_0      COMPLETED             Sobol  0.950319
# 2             2      2_0      COMPLETED             Sobol  0.933184
# 3             3      3_0      COMPLETED             Sobol  0.961408
# 4             4      4_0      COMPLETED             Sobol  0.952053
# 5             5      5_0  EARLY_STOPPED           BoTorch  0.937561
# 6             6      6_0      COMPLETED           BoTorch  0.968631
# 7             7      7_0  EARLY_STOPPED           BoTorch  0.928796
# 8             8      8_0  EARLY_STOPPED           BoTorch  0.934687
# 9             9      9_0  EARLY_STOPPED           BoTorch  0.928492
# 10           10     10_0  EARLY_STOPPED           BoTorch  0.934121
# 11           11     11_0  EARLY_STOPPED           BoTorch  0.927224
# 12           12     12_0      COMPLETED           BoTorch  0.973273
# 13           13     13_0      COMPLETED           BoTorch  0.969323
# 14           14     14_0  EARLY_STOPPED           BoTorch  0.964450
#
#     hidden_size_1  hidden_size_2  learning_rate   dropout
# 0              28             30       0.002936  0.271245
# 1              19            102       0.000179  0.069720
# 2              28             26       0.001377  0.288953
# 3              32             94       0.000180  0.098919
# 4              42             84       0.000282  0.369508
# 5              49            103       0.000106  0.158471
# 6              44            106       0.000428  0.054751
# 7              32             59       0.000109  0.148377
# 8              41            126       0.000100  0.177003
# 9              37             61       0.000102  0.136037
# 10             40            128       0.000105  0.179994
# 11             38             60       0.000106  0.126873
# 12             64            111       0.000223  0.001638
# 13             47            128       0.000478  0.150704
# 14             47             72       0.000435  0.000000

# %% [markdown]
# We can give a very rough estimate of the amount of computational savings due to early stopping, by looking at the total number of steps used when early stopping is used versus the number of steps used if we ran all trials to completion. Note to do a true comparison, one should run full HPO loops with and without early stopping (as early stopping will influence the model and future points selected by the generation strategy).

# %%
map_df = experiment.lookup_data().map_df
trial_to_max_steps = map_df.groupby("trial_index")["steps"].max()
completed_trial_steps = trial_to_max_steps.iloc[0]
savings = 1.0 - trial_to_max_steps.sum() / (
    completed_trial_steps * len(trial_to_max_steps)
)
# TODO format nicer
print(f"A rough estimate of the computational savings is {100 * savings}%.")
# Out:
# A rough estimate of the computational savings is 26.669155555555555%.
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(

# %% [markdown]
# ## Visualizations
#
# Finally, we show a visualization of learning curves versus actual elapsed wall time. This helps to illustrate that stopped trials make room for additional trials to be run.

# %%
# helper function for getting trial start times
def time_started(row):
    trial_index = row["trial_index"]
    return experiment.trials[trial_index].time_run_started


# helper function for getting trial completion times
def time_completed(row):
    trial_index = row["trial_index"]
    return experiment.trials[trial_index].time_completed


# helper function for getting relevant data from experiment
# with early stopping into useful dfs
def early_stopping_exp_to_df(experiment):
    trials_df = exp_to_df(experiment)
    curve_df = experiment.lookup_data().map_df
    training_row_df = (
        curve_df.groupby("trial_index").max().reset_index()[["trial_index", "steps"]]
    )
    trials_df = trials_df.merge(training_row_df, on="trial_index")
    trials_df["time_started"] = trials_df.apply(func=time_started, axis=1)
    trials_df["time_completed"] = trials_df.apply(func=time_completed, axis=1)
    start_time = trials_df["time_started"].min()
    trials_df["time_started_rel"] = (
        trials_df["time_started"] - start_time
    ).dt.total_seconds()
    trials_df["time_completed_rel"] = (
        trials_df["time_completed"] - start_time
    ).dt.total_seconds()
    return trials_df, curve_df


def plot_curves_by_wall_time(trials_df, curve_df):
    trials = set(curve_df["trial_index"])
    fig, ax = plt.subplots(1, 1, figsize=(10, 6))
    ax.set(xlabel="seconds since start", ylabel="validation accuracy")
    for trial_index in trials:
        this_trial_df = curve_df[curve_df["trial_index"] == trial_index]
        start_time_rel = trials_df["time_started_rel"].iloc[trial_index]
        completed_time_rel = trials_df["time_completed_rel"].iloc[trial_index]
        total_steps = trials_df.loc[trial_index, "steps"]
        smoothed_curve = this_trial_df["mean"].rolling(window=3).mean()
        x = (
            start_time_rel
            + (completed_time_rel - start_time_rel)
            / total_steps
            * this_trial_df["steps"]
        )
        ax.plot(
            x,
            smoothed_curve,
            label=f"trial #{trial_index}" if trial_index % 2 == 1 else None,
        )
    ax.legend()

# %%
# wrap in try/except in case of flaky I/O issues
try:
    trials_df, curve_df = early_stopping_exp_to_df(experiment)
    plot_curves_by_wall_time(trials_df, curve_df)
except Exception as e:
    print(f"Encountered exception while plotting results: {e}")
# Out:
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
# [WARNING 07-02 07:14:50] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# /tmp/tmp.UaJQpYqjqJ/Ax-main/ax/core/map_data.py:190: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat(
